# %% [markdown]
# # 运行R（需要在docker环境中运行）

# %% [markdown]
# ## bct数据集

# %%
Rscript BERMUDA_R.R -d "bct" -v 1 -s 1
## 注意不是 Rscript BERMUDA_preprocess.R -d "bct" -v 1 -s 1

# %% [markdown]
# ## bct_del数据集

# %%
Rscript BERMUDA_R.R -d "bct" -v 1 -s 1

# %% [markdown]
# ## sim2数据集

# %%
Rscript BERMUDA_R.R -d "sim2" -v 1 -s 1

# %% [markdown]
# ## macaque4 数据集

# %%
Rscript BERMUDA_R.R -d "macaque4" -v 1 -s 1

# %%
## FullPancreas数据集

# %%
Rscript BERMUDA_R.R -d "FullPancreas" -v 1 -s 1

# %% [markdown]
# # 测试运行BERMUMDA

# %%
# %run run_BERMUDA.py --dataset "macaque4"
# Out:
# method= BERMUDA
# dataset= macaque4
# ['macaque4_batch_2_seurat.csv', 'macaque4_batch_1_seurat.csv', 'macaque4_batch_3_seurat.csv', 'macaque4_batch_4_seurat.csv']
# [[ 1. 27.  1.]
#  [ 1. 42.  1.]
#  [ 2. 22.  1.]
#  [ 2. 43.  1.]
#  [ 2. 54.  1.]
#  [ 3. 25.  1.]
#  [ 3. 44.  1.]
#  [ 3. 55.  1.]
#  [ 3. 58.  1.]
#  [ 4. 23.  1.]
#  [ 4. 49.  1.]
#  [ 4. 53.  1.]
#  [ 5. 26.  1.]
#  [ 5. 32.  1.]
#  [ 5. 47.  1.]
#  [ 5. 57.  1.]
#  [ 6. 24.  1.]
#  [ 6. 46.  1.]
#  [ 6. 56.  1.]
#  [ 7. 24.  1.]
#  [ 7. 33.  1.]
#  [ 7. 34.  1.]
#  [ 7. 45.  1.]
#  [ 7. 56.  1.]
#  [ 8. 28.  1.]
#  [ 8. 45.  1.]
#  [ 8. 56.  1.]
#  [ 9. 35.  1.]
#  [10. 36.  1.]
#  [10. 50.  1.]
#  [10. 60.  1.]
#  [11. 61.  1.]
#  [12. 30.  1.]
#  [12. 48.  1.]
#  [12. 62.  1.]
#  [13. 36.  1.]
#  [13. 50.  1.]
#  [13. 60.  1.]
#  [14. 23.  1.]
#  [14. 37.  1.]
#  [14. 49.  1.]
#  [14. 53.  1.]
#  [14. 64.  1.]
#  [15. 38.  1.]
#  [15. 48.  1.]
#  [15. 63.  1.]
#  [16. 39.  1.]
#  [16. 40.  1.]
#  [16. 51.  1.]
# ...

# %%
# %run run_BERMUDA.py --dataset "FullPancreas"
# Out:
# method= BERMUDA
# dataset= FullPancreas
# ['FullPancreas_batch_2_seurat.csv', 'FullPancreas_batch_5_seurat.csv', 'FullPancreas_batch_7_seurat.csv', 'FullPancreas_batch_6_seurat.csv', 'FullPancreas_batch_4_seurat.csv', 'FullPancreas_batch_3_seurat.csv', 'FullPancreas_batch_1_seurat.csv', 'FullPancreas_batch_8_seurat.csv']
# [[ 1. 12.  1.]
#  [ 1. 27.  1.]
#  [ 1. 37.  1.]
#  [ 1. 48.  1.]
#  [ 1. 56.  1.]
#  [ 2. 30.  1.]
#  [ 2. 39.  1.]
#  [ 2. 46.  1.]
#  [ 2. 58.  1.]
#  [ 3. 13.  1.]
#  [ 3. 20.  1.]
#  [ 3. 25.  1.]
#  [ 3. 33.  1.]
#  [ 3. 35.  1.]
#  [ 3. 45.  1.]
#  [ 3. 55.  1.]
#  [ 3. 63.  1.]
#  [ 4. 10.  1.]
#  [ 4. 16.  1.]
#  [ 4. 18.  1.]
#  [ 4. 19.  1.]
#  [ 4. 24.  1.]
#  [ 4. 31.  1.]
#  [ 4. 36.  1.]
#  [ 4. 47.  1.]
#  [ 4. 54.  1.]
#  [ 4. 62.  1.]
#  [ 5. 14.  1.]
#  [ 5. 17.  1.]
#  [ 5. 26.  1.]
#  [ 5. 38.  1.]
#  [ 5. 49.  1.]
#  [ 5. 57.  1.]
#  [ 5. 64.  1.]
#  [ 5. 65.  1.]
#  [ 6. 21.  1.]
#  [ 7. 15.  1.]
#  [ 7. 23.  1.]
#  [ 7. 28.  1.]
# ...

# %%
nohup python run_BERMUDA.py --dataset "FullPancreas"  > ${save_dir}/${dataset}/${Log_out} 2>&1&
